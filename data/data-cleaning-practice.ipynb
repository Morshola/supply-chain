# %%
3+7
# Out:
# 10

# %%
3+7
# Out:
# 10

# %%
import pandas as pd

# %%
warehouse_reporting = pd.read_csv("data/warehousing-reporting.csv")

# %%
warehouse_reporting.head()
# Out:
#   REORDER (auto-fill) ITEM NO. DATE OF LAST ORDER             ITEM NAME  \
# 0                  OK     A121         20/05/2021  COOLANT RUBBER HOSES
# 1                  OK     B121         20/05/2021  COOLANT RUBBER HOSES
# 2             REORDER     C121         20/05/2021  COOLANT RUBBER HOSES
# 3             REORDER     D121         20/05/2021  COOLANT RUBBER HOSES
# 4                  OK     E121         20/05/2021  COOLANT RUBBER HOSES
#
#                                             VENDOR         STOCK LOCATION  \
# 0  China Grand Automotive Services Group Co., Ltd.  Store Room A, Shelf 2
# 1  China Grand Automotive Services Group Co., Ltd.         Outdoor Pallet
# 2  China Grand Automotive Services Group Co., Ltd.      Basement, Shelf 4
# 3  China Grand Automotive Services Group Co., Ltd.  Store Room A, Shelf 2
# 4  China Grand Automotive Services Group Co., Ltd.         Outdoor Pallet
#
#   COST PER ITEM  STOCK QUANTITY TOTAL VALUE  REORDER LEVEL  \
# ...

# %%
warehouse_reporting.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   REORDER (auto-fill)    245 non-null    object
#  1   ITEM NO.               245 non-null    object
#  2   DATE OF LAST ORDER     245 non-null    object
#  3   ITEM NAME              245 non-null    object
#  4   VENDOR                 245 non-null    object
#  5   STOCK LOCATION         245 non-null    object
#  6   COST PER ITEM          245 non-null    object
#  7   STOCK QUANTITY         245 non-null    int64
#  8   TOTAL VALUE            245 non-null    object
#  9   REORDER LEVEL          245 non-null    int64
#  10  ITEM REORDER QUANTITY  245 non-null    int64
# dtypes: int64(3), object(8)
# memory usage: 21.2+ KB

# %%
warehouse_reporting["COST PER ITEM"] =warehouse_reporting["COST PER ITEM"].str.replace("$", "")
warehouse_reporting["COST PER ITEM"] =warehouse_reporting["COST PER ITEM"].str.replace(",", "")
warehouse_reporting["COST PER ITEM"] =warehouse_reporting["COST PER ITEM"].astype("float")
# Out:
# C:\Users\MOR'SH~1\AppData\Local\Temp/ipykernel_8800/4244192562.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   warehouse_reporting["COST PER ITEM"] =warehouse_reporting["COST PER ITEM"].str.replace("$", "")

# %%
warehouse_reporting.head()
# Out:
#   REORDER (auto-fill) ITEM NO. DATE OF LAST ORDER             ITEM NAME  \
# 0                  OK     A121         20/05/2021  COOLANT RUBBER HOSES
# 1                  OK     B121         20/05/2021  COOLANT RUBBER HOSES
# 2             REORDER     C121         20/05/2021  COOLANT RUBBER HOSES
# 3             REORDER     D121         20/05/2021  COOLANT RUBBER HOSES
# 4                  OK     E121         20/05/2021  COOLANT RUBBER HOSES
#
#                                             VENDOR         STOCK LOCATION  \
# 0  China Grand Automotive Services Group Co., Ltd.  Store Room A, Shelf 2
# 1  China Grand Automotive Services Group Co., Ltd.         Outdoor Pallet
# 2  China Grand Automotive Services Group Co., Ltd.      Basement, Shelf 4
# 3  China Grand Automotive Services Group Co., Ltd.  Store Room A, Shelf 2
# 4  China Grand Automotive Services Group Co., Ltd.         Outdoor Pallet
#
#    COST PER ITEM  STOCK QUANTITY TOTAL VALUE  REORDER LEVEL  \
# ...

# %%
warehouse_reporting["DATE OF THE LAST ORDER"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MOR'SH~1\AppData\Local\Temp/ipykernel_13292/3425746277.py in <module>
# ----> 1 warehouse_reporting["DATE OF THE LAST ORDER"]
#
# NameError: name 'warehouse_reporting' is not defined

# %%
import pandas as pd
warehouse_reporting = pd.read_csv("warehousing-reporting.csv")
warehouse_reporting.head()
# Out:
#   REORDER (auto-fill) ITEM NO. DATE OF LAST ORDER             ITEM NAME  \
# 0                  OK     A121         20/05/2021  COOLANT RUBBER HOSES
# 1                  OK     B121         20/05/2021  COOLANT RUBBER HOSES
# 2             REORDER     C121         20/05/2021  COOLANT RUBBER HOSES
# 3             REORDER     D121         20/05/2021  COOLANT RUBBER HOSES
# 4                  OK     E121         20/05/2021  COOLANT RUBBER HOSES
#
#                                             VENDOR         STOCK LOCATION  \
# 0  China Grand Automotive Services Group Co., Ltd.  Store Room A, Shelf 2
# 1  China Grand Automotive Services Group Co., Ltd.         Outdoor Pallet
# 2  China Grand Automotive Services Group Co., Ltd.      Basement, Shelf 4
# 3  China Grand Automotive Services Group Co., Ltd.  Store Room A, Shelf 2
# 4  China Grand Automotive Services Group Co., Ltd.         Outdoor Pallet
#
#   COST PER ITEM  STOCK QUANTITY TOTAL VALUE  REORDER LEVEL  \
# ...

# %%
warehouse_reporting.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   REORDER (auto-fill)    245 non-null    object
#  1   ITEM NO.               245 non-null    object
#  2   DATE OF LAST ORDER     245 non-null    object
#  3   ITEM NAME              245 non-null    object
#  4   VENDOR                 245 non-null    object
#  5   STOCK LOCATION         245 non-null    object
#  6   COST PER ITEM          245 non-null    object
#  7   STOCK QUANTITY         245 non-null    int64
#  8   TOTAL VALUE            245 non-null    object
#  9   REORDER LEVEL          245 non-null    int64
#  10  ITEM REORDER QUANTITY  245 non-null    int64
# dtypes: int64(3), object(8)
# memory usage: 21.2+ KB

# %%
warehouse_reporting.dtypes
# Out:
# REORDER (auto-fill)      object
# ITEM NO.                 object
# DATE OF LAST ORDER       object
# ITEM NAME                object
# VENDOR                   object
# STOCK LOCATION           object
# COST PER ITEM            object
# STOCK QUANTITY            int64
# TOTAL VALUE              object
# REORDER LEVEL             int64
# ITEM REORDER QUANTITY     int64
# dtype: object

# %%
sma_data = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/Standard_Metropolitan_Areas_Data-data.csv")
sma_data.shape
sma_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   land_area       99 non-null     int64
#  1   percent_city    99 non-null     float64
#  2   percent_senior  99 non-null     float64
#  3   physicians      99 non-null     int64
#  4   hospital_beds   99 non-null     int64
#  5   graduates       99 non-null     float64
#  6   work_force      99 non-null     float64
#  7   income          99 non-null     int64
#  8   region          99 non-null     int64
#  9   crime_rate      99 non-null     float64
# dtypes: float64(5), int64(5)
# memory usage: 7.9 KB

# %%
sma_data.head()
# Out:
#    land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0       1384          78.1            12.3       25627          69678
# 1       3719          43.9             9.4       13326          43292
# 2       3553          37.4            10.7        9724          33731
# 3       3916          29.9             8.8        6402          24167
# 4       2480          31.5            10.5        8502          16751
#
#    graduates  work_force  income  region  crime_rate
# 0       50.1      4083.9   72100       1       75.55
# 1       53.9      3305.9   54542       2       56.03
# 2       50.6      2066.3   33216       1       41.32
# 3       52.2      1966.7   32906       2       67.38
# 4       66.1      1514.5   26573       4       80.19

# %%
sma_data.iloc[0:4, 4]
# Out:
# 0    69678
# 1    43292
# 2    33731
# 3    24167
# Name: hospital_beds, dtype: int64

# %%
import pandas as pd

# %%
warehouse_reporting = pd.read_csv("warehousing-reporting.csv")
warehouse_reporting.head()
# Out:
#   REORDER (auto-fill) ITEM NO. DATE OF LAST ORDER             ITEM NAME  \
# 0                  OK     A121         20/05/2021  COOLANT RUBBER HOSES
# 1                  OK     B121         20/05/2021  COOLANT RUBBER HOSES
# 2             REORDER     C121         20/05/2021  COOLANT RUBBER HOSES
# 3             REORDER     D121         20/05/2021  COOLANT RUBBER HOSES
# 4                  OK     E121         20/05/2021  COOLANT RUBBER HOSES
#
#                                             VENDOR         STOCK LOCATION  \
# 0  China Grand Automotive Services Group Co., Ltd.  Store Room A, Shelf 2
# 1  China Grand Automotive Services Group Co., Ltd.         Outdoor Pallet
# 2  China Grand Automotive Services Group Co., Ltd.      Basement, Shelf 4
# 3  China Grand Automotive Services Group Co., Ltd.  Store Room A, Shelf 2
# 4  China Grand Automotive Services Group Co., Ltd.         Outdoor Pallet
#
#   COST PER ITEM  STOCK QUANTITY TOTAL VALUE  REORDER LEVEL  \
# ...

# %%
warehouse_reporting["DATE OF LAST ORDER"] = pd.datetime9 = (warehouse_reporting["DATE OF LAST ORDER"])

# %%
warehouse_reporting.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   REORDER (auto-fill)    245 non-null    object
#  1   ITEM NO.               245 non-null    object
#  2   DATE OF LAST ORDER     245 non-null    datetime64[ns]
#  3   ITEM NAME              245 non-null    object
#  4   VENDOR                 245 non-null    object
#  5   STOCK LOCATION         245 non-null    object
#  6   COST PER ITEM          245 non-null    object
#  7   STOCK QUANTITY         245 non-null    int64
#  8   TOTAL VALUE            245 non-null    object
#  9   REORDER LEVEL          245 non-null    int64
#  10  ITEM REORDER QUANTITY  245 non-null    int64
# dtypes: datetime64[ns](1), int64(3), object(7)
# memory usage: 21.2+ KB

# %%
warehouse_reporting.head()
# Out:
#   REORDER (auto-fill) ITEM NO. DATE OF LAST ORDER             ITEM NAME  \
# 0                  OK     A121         2021-05-20  COOLANT RUBBER HOSES
# 1                  OK     B121         2021-05-20  COOLANT RUBBER HOSES
# 2             REORDER     C121         2021-05-20  COOLANT RUBBER HOSES
# 3             REORDER     D121         2021-05-20  COOLANT RUBBER HOSES
# 4                  OK     E121         2021-05-20  COOLANT RUBBER HOSES
#
#                                             VENDOR         STOCK LOCATION  \
# 0  China Grand Automotive Services Group Co., Ltd.  Store Room A, Shelf 2
# 1  China Grand Automotive Services Group Co., Ltd.         Outdoor Pallet
# 2  China Grand Automotive Services Group Co., Ltd.      Basement, Shelf 4
# 3  China Grand Automotive Services Group Co., Ltd.  Store Room A, Shelf 2
# 4  China Grand Automotive Services Group Co., Ltd.         Outdoor Pallet
#
#   COST PER ITEM  STOCK QUANTITY TOTAL VALUE  REORDER LEVEL  \
# ...

# %%
warehouse_reporting.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   REORDER (auto-fill)    245 non-null    object
#  1   ITEM NO.               245 non-null    object
#  2   DATE OF LAST ORDER     245 non-null    object
#  3   ITEM NAME              245 non-null    object
#  4   VENDOR                 245 non-null    object
#  5   STOCK LOCATION         245 non-null    object
#  6   COST PER ITEM          245 non-null    object
#  7   STOCK QUANTITY         245 non-null    int64
#  8   TOTAL VALUE            245 non-null    object
#  9   REORDER LEVEL          245 non-null    int64
#  10  ITEM REORDER QUANTITY  245 non-null    int64
# dtypes: int64(3), object(8)
# memory usage: 21.2+ KB

# %%
warehouse_reporting["DATE OF LAST ORDER"] =warehouse_reporting["DATE OF LAST ORDER"].astype("datetime64[ns]")

# %%
warehouse_reporting.head()
# Out:
#   REORDER (auto-fill) ITEM NO. DATE OF LAST ORDER             ITEM NAME  \
# 0                  OK     A121         2021-05-20  COOLANT RUBBER HOSES
# 1                  OK     B121         2021-05-20  COOLANT RUBBER HOSES
# 2             REORDER     C121         2021-05-20  COOLANT RUBBER HOSES
# 3             REORDER     D121         2021-05-20  COOLANT RUBBER HOSES
# 4                  OK     E121         2021-05-20  COOLANT RUBBER HOSES
#
#                                             VENDOR         STOCK LOCATION  \
# 0  China Grand Automotive Services Group Co., Ltd.  Store Room A, Shelf 2
# 1  China Grand Automotive Services Group Co., Ltd.         Outdoor Pallet
# 2  China Grand Automotive Services Group Co., Ltd.      Basement, Shelf 4
# 3  China Grand Automotive Services Group Co., Ltd.  Store Room A, Shelf 2
# 4  China Grand Automotive Services Group Co., Ltd.         Outdoor Pallet
#
#   COST PER ITEM  STOCK QUANTITY TOTAL VALUE  REORDER LEVEL  \
# ...

# %%
warehouse_reporting.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   REORDER (auto-fill)    245 non-null    object
#  1   ITEM NO.               245 non-null    object
#  2   DATE OF LAST ORDER     245 non-null    datetime64[ns]
#  3   ITEM NAME              245 non-null    object
#  4   VENDOR                 245 non-null    object
#  5   STOCK LOCATION         245 non-null    object
#  6   COST PER ITEM          245 non-null    object
#  7   STOCK QUANTITY         245 non-null    int64
#  8   TOTAL VALUE            245 non-null    object
#  9   REORDER LEVEL          245 non-null    int64
#  10  ITEM REORDER QUANTITY  245 non-null    int64
# dtypes: datetime64[ns](1), int64(3), object(7)
# memory usage: 21.2+ KB

# %%
import pandas as pd

# %%
warehouse_reporting = pd.read_csv("warehousing-reporting.csv")

# %%
warehouse_reporting.head()
# Out:
#   REORDER (auto-fill) ITEM NO. DATE OF LAST ORDER             ITEM NAME  \
# 0                  OK     A121         20/05/2021  COOLANT RUBBER HOSES
# 1                  OK     B121         20/05/2021  COOLANT RUBBER HOSES
# 2             REORDER     C121         20/05/2021  COOLANT RUBBER HOSES
# 3             REORDER     D121         20/05/2021  COOLANT RUBBER HOSES
# 4                  OK     E121         20/05/2021  COOLANT RUBBER HOSES
#
#                                             VENDOR         STOCK LOCATION  \
# 0  China Grand Automotive Services Group Co., Ltd.  Store Room A, Shelf 2
# 1  China Grand Automotive Services Group Co., Ltd.         Outdoor Pallet
# 2  China Grand Automotive Services Group Co., Ltd.      Basement, Shelf 4
# 3  China Grand Automotive Services Group Co., Ltd.  Store Room A, Shelf 2
# 4  China Grand Automotive Services Group Co., Ltd.         Outdoor Pallet
#
#   COST PER ITEM  STOCK QUANTITY TOTAL VALUE  REORDER LEVEL  \
# ...

# %%
warehouse_reporting.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   REORDER (auto-fill)    245 non-null    object
#  1   ITEM NO.               245 non-null    object
#  2   DATE OF LAST ORDER     245 non-null    object
#  3   ITEM NAME              245 non-null    object
#  4   VENDOR                 245 non-null    object
#  5   STOCK LOCATION         245 non-null    object
#  6   COST PER ITEM          245 non-null    object
#  7   STOCK QUANTITY         245 non-null    int64
#  8   TOTAL VALUE            245 non-null    object
#  9   REORDER LEVEL          245 non-null    int64
#  10  ITEM REORDER QUANTITY  245 non-null    int64
# dtypes: int64(3), object(8)
# memory usage: 21.2+ KB

# %%
warehouse_reporting ["DATE OF LAST ORDER"] = warehouse_reporting["DATE OF LAST ORDER"].astype("datetime64[ns]")

# %%
warehouse_reporting.head()
# Out:
#   REORDER (auto-fill) ITEM NO. DATE OF LAST ORDER             ITEM NAME  \
# 0                  OK     A121         2021-05-20  COOLANT RUBBER HOSES
# 1                  OK     B121         2021-05-20  COOLANT RUBBER HOSES
# 2             REORDER     C121         2021-05-20  COOLANT RUBBER HOSES
# 3             REORDER     D121         2021-05-20  COOLANT RUBBER HOSES
# 4                  OK     E121         2021-05-20  COOLANT RUBBER HOSES
#
#                                             VENDOR         STOCK LOCATION  \
# 0  China Grand Automotive Services Group Co., Ltd.  Store Room A, Shelf 2
# 1  China Grand Automotive Services Group Co., Ltd.         Outdoor Pallet
# 2  China Grand Automotive Services Group Co., Ltd.      Basement, Shelf 4
# 3  China Grand Automotive Services Group Co., Ltd.  Store Room A, Shelf 2
# 4  China Grand Automotive Services Group Co., Ltd.         Outdoor Pallet
#
#   COST PER ITEM  STOCK QUANTITY TOTAL VALUE  REORDER LEVEL  \
# ...

# %%
warehouse_reporting.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   REORDER (auto-fill)    245 non-null    object
#  1   ITEM NO.               245 non-null    object
#  2   DATE OF LAST ORDER     245 non-null    datetime64[ns]
#  3   ITEM NAME              245 non-null    object
#  4   VENDOR                 245 non-null    object
#  5   STOCK LOCATION         245 non-null    object
#  6   COST PER ITEM          245 non-null    object
#  7   STOCK QUANTITY         245 non-null    int64
#  8   TOTAL VALUE            245 non-null    object
#  9   REORDER LEVEL          245 non-null    int64
#  10  ITEM REORDER QUANTITY  245 non-null    int64
# dtypes: datetime64[ns](1), int64(3), object(7)
# memory usage: 21.2+ KB

# %%
warehouse_reporting["TOTAL VALUE"].head()
# Out:
# 0    $3,782.00
# 1      $717.00
# 2      $326.25
# 3      $221.25
# 4    $2,424.00
# Name: TOTAL VALUE, dtype: object

# %%
warehouse_reporting["TOTAL VALUE"] = warehouse_reporting["TOTAL VALUE"].str.replace("$","")
warehouse_reporting["TOTAL VALUE"] = warehouse_reporting["TOTAL VALUE"].str.replace(",","")
warehouse_reporting["TOTAL VALUE"] = warehouse_reporting["TOTAL VALUE"].astype("float")
# Out:
# C:\Users\MOR'SH~1\AppData\Local\Temp/ipykernel_240/1266703022.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   warehouse_reporting["TOTAL VALUE"] = warehouse_reporting["TOTAL VALUE"].str.replace("$","")

# %%
warehouse_reporting.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   REORDER (auto-fill)    245 non-null    object
#  1   ITEM NO.               245 non-null    object
#  2   DATE OF LAST ORDER     245 non-null    datetime64[ns]
#  3   ITEM NAME              245 non-null    object
#  4   VENDOR                 245 non-null    object
#  5   STOCK LOCATION         245 non-null    object
#  6   COST PER ITEM          245 non-null    object
#  7   STOCK QUANTITY         245 non-null    int64
#  8   TOTAL VALUE            245 non-null    float64
#  9   REORDER LEVEL          245 non-null    int64
#  10  ITEM REORDER QUANTITY  245 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(6)
# memory usage: 21.2+ KB

# %%
warehouse_reporting["TOTAL VALUE"].head()
# Out:
# 0    3782.00
# 1     717.00
# 2     326.25
# 3     221.25
# 4    2424.00
# Name: TOTAL VALUE, dtype: float64

# %%
warehouse_reporting["TOTAL VALUE"].head()
# Out:
# 0    3782.00
# 1     717.00
# 2     326.25
# 3     221.25
# 4    2424.00
# Name: TOTAL VALUE, dtype: float64

# %%
import pandas as pd

# %%
warehouse_reporting = pd.read_csv("warehousing-reporting.csv")

# %%
warehouse_reporting.head()
# Out:
#   reorder_(auto-fill) item_no date_of_last_order             item_name  \
# 0                  OK    A121         20/05/2021  COOLANT RUBBER HOSES
# 1                  OK    B121         20/05/2021  COOLANT RUBBER HOSES
# 2             REORDER    C121         20/05/2021  COOLANT RUBBER HOSES
# 3             REORDER    D121         20/05/2021  COOLANT RUBBER HOSES
# 4                  OK    E121         20/05/2021  COOLANT RUBBER HOSES
#
#                                             vendor         stock_location  \
# 0  China Grand Automotive Services Group Co., Ltd.  Store Room A, Shelf 2
# 1  China Grand Automotive Services Group Co., Ltd.         Outdoor Pallet
# 2  China Grand Automotive Services Group Co., Ltd.      Basement, Shelf 4
# 3  China Grand Automotive Services Group Co., Ltd.  Store Room A, Shelf 2
# 4  China Grand Automotive Services Group Co., Ltd.         Outdoor Pallet
#
#   cost_per_item  stock_quantity total_value  reorder_level  \
# ...

# %%
warehouse_reporting["new_column"] = warehouse_reporting['stock_quantity'] < warehouse_reporting['reorder_level']
warehouse_reporting.head()
# Out:
#   reorder_(auto-fill) item_no date_of_last_order             item_name  \
# 0                  OK    A121         20/05/2021  COOLANT RUBBER HOSES
# 1                  OK    B121         20/05/2021  COOLANT RUBBER HOSES
# 2             REORDER    C121         20/05/2021  COOLANT RUBBER HOSES
# 3             REORDER    D121         20/05/2021  COOLANT RUBBER HOSES
# 4                  OK    E121         20/05/2021  COOLANT RUBBER HOSES
#
#                                             vendor         stock_location  \
# 0  China Grand Automotive Services Group Co., Ltd.  Store Room A, Shelf 2
# 1  China Grand Automotive Services Group Co., Ltd.         Outdoor Pallet
# 2  China Grand Automotive Services Group Co., Ltd.      Basement, Shelf 4
# 3  China Grand Automotive Services Group Co., Ltd.  Store Room A, Shelf 2
# 4  China Grand Automotive Services Group Co., Ltd.         Outdoor Pallet
#
#   cost_per_item  stock_quantity total_value  reorder_level  \
# ...
